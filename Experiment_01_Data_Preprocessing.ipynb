# %% [markdown]
# <a href="https://colab.research.google.com/github/aarti-raut/AML-Lab-Experiments/blob/main/Experiment_01_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 1: Data Preprocessing
# **Dataset:** Iris Dataset (UCI ML Repository)
# **Aim:** Apply data preprocessing techniques to make data suitable for machine learning.

# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# Step 2: Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['species'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

print('=== First 5 rows of dataset ===')
print(df.head())
# Out:
# === First 5 rows of dataset ===
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
# Step 3: Check basic info and missing values
print('=== Dataset Shape ===')
print(df.shape)

print('\n=== Dataset Info ===')
print(df.info())

print('\n=== Missing Values ===')
print(df.isnull().sum())

print('\n=== Basic Statistics ===')
print(df.describe())
# Out:
# === Dataset Shape ===
# (150, 6)
#
# === Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
#  5   species            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#
# === Missing Values ===
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# species              0
# dtype: int64
#
# === Basic Statistics ===
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# ...

# %%
# Step 4: Introduce some missing values artificially to practice handling
df_copy = df.copy()
np.random.seed(42)
missing_indices = np.random.choice(df_copy.index, size=10, replace=False)
df_copy.loc[missing_indices, 'sepal length (cm)'] = np.nan

print('Missing values after introduction:')
print(df_copy.isnull().sum())

# Fill missing values with mean
df_copy['sepal length (cm)'] = df_copy['sepal length (cm)'].fillna(df_copy['sepal length (cm)'].mean())
print('\nMissing values after filling with mean:')
print(df_copy.isnull().sum())
# Out:
# Missing values after introduction:
# sepal length (cm)    10
# sepal width (cm)      0
# petal length (cm)     0
# petal width (cm)      0
# target                0
# species               0
# species_encoded       0
# dtype: int64
#
# Missing values after filling with mean:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# species              0
# species_encoded      0
# dtype: int64

# %%
# Step 5: Label Encoding (converting text labels to numbers)
le = LabelEncoder()
df['species_encoded'] = le.fit_transform(df['species'])
print('=== Label Encoding ===')
print(df[['species', 'species_encoded']].drop_duplicates())
# Out:
# === Label Encoding ===
#         species  species_encoded
# 0        setosa                0
# 50   versicolor                1
# 100   virginica                2

# %%
# Step 6: Feature Scaling using StandardScaler
X = df[iris.feature_names]
y = df['target']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=iris.feature_names)

print('=== Before Scaling ===')
print(X.describe().round(2))

print('\n=== After Standard Scaling ===')
print(X_scaled_df.describe().round(2))
# Out:
# === Before Scaling ===
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count             150.00            150.00             150.00
# mean                5.84              3.06               3.76
# std                 0.83              0.44               1.77
# min                 4.30              2.00               1.00
# 25%                 5.10              2.80               1.60
# 50%                 5.80              3.00               4.35
# 75%                 6.40              3.30               5.10
# max                 7.90              4.40               6.90
#
#        petal width (cm)
# count            150.00
# mean               1.20
# std                0.76
# min                0.10
# 25%                0.30
# 50%                1.30
# 75%                1.80
# max                2.50
#
# === After Standard Scaling ===
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...

# %%
# Step 7: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

print('=== Train-Test Split ===')
print(f'Training set size: {X_train.shape[0]} samples')
print(f'Testing set size:  {X_test.shape[0]} samples')
print('\nPreprocessing complete! Data is ready for machine learning.')
# Out:
# === Train-Test Split ===
# Training set size: 120 samples
# Testing set size:  30 samples
#
# Preprocessing complete! Data is ready for machine learning.
